# %% [markdown]
# <table width=100%; style="background-color:#caf0fa";>
#     <tr style="background-color:#caf0fa">
#         <td>
#             <h1 style="text-align:right">
#                 Python for Data Science Training - Week 3
#             </h1>
#         </td>
#         <td>
#             <img src="../img/jica-logo.png" alt = "JICA Training" style = "width: 100px;"/>
#         </td>
#     </tr>
# </table>
#
# # Today's Contents
# 1. Pandas
#
# ---
#
# # 1. Pandas

# %% [markdown]
# ## 1-1. Read file
# ```python
# import pandas as pd
#
# # Read CSV data
# df = pd.read_csv(csv_file)
# # Read Excel data
# df = pd.read_excel(excel_file)
# # Read Stata file
# df = pd.read_stata(stata .dta file)
# ```

# %%
import pandas as pd

# %% [markdown]
# Sample Data: [GDP Growth from World Development Indicator](https://data.worldbank.org/indicator/NY.GDP.MKTP.KD.ZG?view=chart)

# %%
# Access to dataset
# `..` means "Go to the parent folder"
data = 'data/GDP_growth_from_WDI/API_NY.GDP.MKTP.KD.ZG_DS2_en_csv_v2_2252300.csv'

# %%
# Read csv data
df = pd.read_csv(data, header = 2)

# %%
# Let's first check datatype
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# `df.head()` method gives you the first 5 lines of the dataframe.
# `df.tail()` method gives you the last 5 lines of the dataframe.

# %%
df.head()
# Out:
#   Country Name Country Code         Indicator Name     Indicator Code  1960  \
# 0        Aruba          ABW  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 1  Afghanistan          AFG  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 2       Angola          AGO  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 3      Albania          ALB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
# 4      Andorra          AND  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG   NaN
#
#    1961  1962  1963  1964  1965  ...       2012      2013      2014      2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  -1.369863  4.198232  0.300000  5.700001
# 1   NaN   NaN   NaN   NaN   NaN  ...  12.752287  5.600745  2.724543  1.451315
# 2   NaN   NaN   NaN   NaN   NaN  ...   8.542188  4.954545  4.822628  0.943572
# 3   NaN   NaN   NaN   NaN   NaN  ...   1.417526  1.001987  1.774487  2.218752
# 4   NaN   NaN   NaN   NaN   NaN  ...  -4.974444 -3.547597  2.504466  1.434140
#
#        2016      2017      2018      2019  2020  Unnamed: 65
# 0  2.100000  1.999999       NaN       NaN   NaN          NaN
# 1  2.260314  2.647003  1.189228  3.911603   NaN          NaN
# 2 -2.580050 -0.147213 -2.003630 -0.624644   NaN          NaN
# 3  3.314805  3.802197  4.071301  2.240070   NaN          NaN
# 4  3.709678  0.346072  1.588765  1.849238   NaN          NaN
#
# [5 rows x 66 columns]

# %%
df.tail()
# Out:
#      Country Name Country Code         Indicator Name     Indicator Code  \
# 259        Kosovo          XKX  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 260   Yemen, Rep.          YEM  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 261  South Africa          ZAF  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 262        Zambia          ZMB  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
# 263      Zimbabwe          ZWE  GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
#
#      1960      1961      1962      1963       1964       1965  ...       2012  \
# 259   NaN       NaN       NaN       NaN        NaN        NaN  ...   2.810262
# 260   NaN       NaN       NaN       NaN        NaN        NaN  ...   2.392886
# 261   NaN  3.844751  6.177883  7.373613   7.939782   6.122761  ...   2.213355
# 262   NaN  1.361382 -2.490839  3.272393  12.214048  16.647456  ...   7.597593
# 263   NaN  6.316157  1.434471  6.244345  -1.106172   4.910571  ...  16.665429
#
#          2013      2014       2015      2016      2017      2018      2019  \
# 259  3.439551  1.222168   4.095194  4.070950  4.225630  3.815620  4.171659
# 260  4.823415 -0.188591 -27.994439 -9.375060 -5.072010  0.752599  2.097414
# 261  2.485201  1.846992   1.193733  0.399088  1.414513  0.787056  0.152583
# 262  5.057232  4.697992   2.920375  3.776679  3.504336  4.034378  1.441785
# 263  1.989493  2.376929   1.779873  0.755869  4.704035  4.829674 -8.100000
#
#      2020  Unnamed: 65
# 259   NaN          NaN
# 260   NaN          NaN
# 261   NaN          NaN
# 262   NaN          NaN
# 263   NaN          NaN
#
# [5 rows x 66 columns]

# %% [markdown]
# `df.columns` allows you to access column names.

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', 'Unnamed: 65'],
#       dtype='object')

# %% [markdown]
# It's always recommended to find the shape of the dataframe.

# %%
# .shape method
df.shape # (rows, columns)
# Out:
# (264, 66)

# %%
# Find length of dataframw with `len()`
len(df)
# Out:
# 264

# %%
row = df.shape[0]
col = df.shape[1]
print('Dataframe\'s shape is {row} and {col}'.format(row = row, col = col))
# Out:
# Dataframe's shape is 264 and 66

# %% [markdown]
# Let's focus on the last 6 years (2015-2020).
# Selecting specific columns can be implemented as below:
#
# ```python
# new_df = df[[col1, col2, col3, ...]]
# ```
# or, this can be much simpler by writing:
# ```python
# selected_cols = [col1, col2, col3,...]
# new_df = df[selected_cols]
# ```
# In Python, using `[ ]` is called *indexing*.

# %%
# Let's do it
cols = ['Country Name', 'Country Code','2015', '2016', '2017', '2018', '2019', '2020']
selected_df = df[cols]

# %%
# Let's call `.head()` method again.
selected_df.head()
# Out:
#   Country Name Country Code      2015      2016      2017      2018      2019  \
# 0        Aruba          ABW  5.700001  2.100000  1.999999       NaN       NaN
# 1  Afghanistan          AFG  1.451315  2.260314  2.647003  1.189228  3.911603
# 2       Angola          AGO  0.943572 -2.580050 -0.147213 -2.003630 -0.624644
# 3      Albania          ALB  2.218752  3.314805  3.802197  4.071301  2.240070
# 4      Andorra          AND  1.434140  3.709678  0.346072  1.588765  1.849238
#
#    2020
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %% [markdown]
# Find basic statistics of the data
# `df.describe()`
#
# This automatically calculates basic statistcis. It ignores columns with string type.

# %%
selected_df.describe()
# Out:
#              2015        2016        2017        2018        2019  2020
# count  250.000000  249.000000  249.000000  247.000000  234.000000   0.0
# mean     2.743262    3.116479    3.244636    3.054929    2.649466   NaN
# std      4.402600    3.532162    3.516396    3.028009    2.892753   NaN
# min    -27.994439  -10.190385   -6.799428  -19.607843   -8.100000   NaN
# 25%      1.406967    1.637838    1.809054    1.928425    1.189480   NaN
# 50%      2.954788    3.187817    3.322433    3.110836    2.292222   NaN
# 75%      4.533975    4.681954    4.757242    4.486979    4.361645   NaN
# max     25.162533   28.311057   26.680903   15.132800   18.723525   NaN

# %% [markdown]
# We can visualize this! -> We'll cover visualization next week!

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
selected_df.describe().T[['mean']].plot(kind = 'line')
plt.title('GDP Growth Global Average'); plt.ylabel('Percent');

# %% [markdown]
# Let's access to the individual column.
# `df['column_name']`

# %%
# See individual country name
selected_df['Country Name']
# Out:
# 0             Aruba
# 1       Afghanistan
# 2            Angola
# 3           Albania
# 4           Andorra
#            ...
# 259          Kosovo
# 260     Yemen, Rep.
# 261    South Africa
# 262          Zambia
# 263        Zimbabwe
# Name: Country Name, Length: 264, dtype: object

# %%
# Finding unique value
selected_df['Country Name'].unique()
# Out:
# array(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czech Republic', 'Germany', 'Djibouti', 'Dominica',
#        'Denmark', 'Dominican Republic', 'Algeria',
#        'East Asia & Pacific (excluding high income)',
#        'Early-demographic dividend', 'East Asia & Pacific',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia', 'Ecuador', 'Egypt, Arab Rep.',
#        'Euro area', 'Eritrea', 'Spain', 'Estonia', 'Ethiopia',
#        'European Union', 'Fragile and conflict affected situations',
#        'Finland', 'Fiji', 'France', 'Faroe Islands',
#        'Micronesia, Fed. Sts.', 'Gabon', 'United Kingdom', 'Georgia',
#        'Ghana', 'Gibraltar', 'Guinea', 'Gambia, The', 'Guinea-Bissau',
#        'Equatorial Guinea', 'Greece', 'Grenada', 'Greenland', 'Guatemala',
#        'Guam', 'Guyana', 'High income', 'Hong Kong SAR, China',
#        'Honduras', 'Heavily indebted poor countries (HIPC)', 'Croatia',
#        'Haiti', 'Hungary', 'IBRD only', 'IDA & IBRD total', 'IDA total',
#        'IDA blend', 'Indonesia', 'IDA only', 'Isle of Man', 'India',
#        'Not classified', 'Ireland', 'Iran, Islamic Rep.', 'Iraq',
#        'Iceland', 'Israel', 'Italy', 'Jamaica', 'Jordan', 'Japan',
#        'Kazakhstan', 'Kenya', 'Kyrgyz Republic', 'Cambodia', 'Kiribati',
#        'St. Kitts and Nevis', 'Korea, Rep.', 'Kuwait',
#        'Latin America & Caribbean (excluding high income)', 'Lao PDR',
#        'Lebanon', 'Liberia', 'Libya', 'St. Lucia',
#        'Latin America & Caribbean',
#        'Least developed countries: UN classification', 'Low income',
#        'Liechtenstein', 'Sri Lanka', 'Lower middle income',
#        'Low & middle income', 'Lesotho', 'Late-demographic dividend',
#        'Lithuania', 'Luxembourg', 'Latvia', 'Macao SAR, China',
#        'St. Martin (French part)', 'Morocco', 'Monaco', 'Moldova',
#        'Madagascar', 'Maldives', 'Middle East & North Africa', 'Mexico',
#        'Marshall Islands', 'Middle income', 'North Macedonia', 'Mali',
#        'Malta', 'Myanmar',
#        'Middle East & North Africa (excluding high income)', 'Montenegro',
#        'Mongolia', 'Northern Mariana Islands', 'Mozambique', 'Mauritania',
#        'Mauritius', 'Malawi', 'Malaysia', 'North America', 'Namibia',
#        'New Caledonia', 'Niger', 'Nigeria', 'Nicaragua', 'Netherlands',
#        'Norway', 'Nepal', 'Nauru', 'New Zealand', 'OECD members', 'Oman',
#        'Other small states', 'Pakistan', 'Panama', 'Peru', 'Philippines',
#        'Palau', 'Papua New Guinea', 'Poland', 'Pre-demographic dividend',
#        'Puerto Rico', 'Korea, Dem. People’s Rep.', 'Portugal', 'Paraguay',
#        'West Bank and Gaza', 'Pacific island small states',
#        'Post-demographic dividend', 'French Polynesia', 'Qatar',
#        'Romania', 'Russian Federation', 'Rwanda', 'South Asia',
#        'Saudi Arabia', 'Sudan', 'Senegal', 'Singapore', 'Solomon Islands',
#        'Sierra Leone', 'El Salvador', 'San Marino', 'Somalia', 'Serbia',
#        'Sub-Saharan Africa (excluding high income)', 'South Sudan',
#        'Sub-Saharan Africa', 'Small states', 'Sao Tome and Principe',
#        'Suriname', 'Slovak Republic', 'Slovenia', 'Sweden', 'Eswatini',
#        'Sint Maarten (Dutch part)', 'Seychelles', 'Syrian Arab Republic',
#        'Turks and Caicos Islands', 'Chad',
#        'East Asia & Pacific (IDA & IBRD countries)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'Togo', 'Thailand',
#        'Tajikistan', 'Turkmenistan',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Timor-Leste', 'Middle East & North Africa (IDA & IBRD countries)',
#        'Tonga', 'South Asia (IDA & IBRD)',
#        'Sub-Saharan Africa (IDA & IBRD countries)', 'Trinidad and Tobago',
#        'Tunisia', 'Turkey', 'Tuvalu', 'Tanzania', 'Uganda', 'Ukraine',
#        'Upper middle income', 'Uruguay', 'United States', 'Uzbekistan',
#        'St. Vincent and the Grenadines', 'Venezuela, RB',
#        'British Virgin Islands', 'Virgin Islands (U.S.)', 'Vietnam',
#        'Vanuatu', 'World', 'Samoa', 'Kosovo', 'Yemen, Rep.',
#        'South Africa', 'Zambia', 'Zimbabwe'], dtype=object)

# %%
# Finding the number of unique value
selected_df['Country Name'].nunique()
# Out:
# 264

# %% [markdown]
# Dealing with Null value.
# Finding null value is `df.isnull()`

# %%
selected_df.isnull()
# Out:
#      Country Name  Country Code   2015   2016   2017   2018   2019  2020
# 0           False         False  False  False  False   True   True  True
# 1           False         False  False  False  False  False  False  True
# 2           False         False  False  False  False  False  False  True
# 3           False         False  False  False  False  False  False  True
# 4           False         False  False  False  False  False  False  True
# ..            ...           ...    ...    ...    ...    ...    ...   ...
# 259         False         False  False  False  False  False  False  True
# 260         False         False  False  False  False  False  False  True
# 261         False         False  False  False  False  False  False  True
# 262         False         False  False  False  False  False  False  True
# 263         False         False  False  False  False  False  False  True
#
# [264 rows x 8 columns]

# %% [markdown]
# This is useful by adding `sum()`.

# %%
selected_df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# 2015             14
# 2016             15
# 2017             15
# 2018             17
# 2019             30
# 2020            264
# dtype: int64

# %%
# Percentage can be cauculated by simply deviding with df length.
selected_df.isnull().sum() / len(selected_df)
# Out:
# Country Name    0.000000
# Country Code    0.000000
# 2015            0.053030
# 2016            0.056818
# 2017            0.056818
# 2018            0.064394
# 2019            0.113636
# 2020            1.000000
# dtype: float64

# %%
# If you want to show them by multiplying by 100, just do it with `* 100`.
selected_df.isnull().sum() / len(selected_df) * 100
# Out:
# Country Name      0.000000
# Country Code      0.000000
# 2015              5.303030
# 2016              5.681818
# 2017              5.681818
# 2018              6.439394
# 2019             11.363636
# 2020            100.000000
# dtype: float64

# %%
# Let's drop the column of 2020 with `.drop` method
# In Python, axis = 0 is row wise, axis = 1 is column wise
selected_df = selected_df.drop(columns = ['2020'], axis = 1)

# %%
selected_df.head()
# Out:
#   Country Name Country Code      2015      2016      2017      2018      2019
# 0        Aruba          ABW  5.700001  2.100000  1.999999       NaN       NaN
# 1  Afghanistan          AFG  1.451315  2.260314  2.647003  1.189228  3.911603
# 2       Angola          AGO  0.943572 -2.580050 -0.147213 -2.003630 -0.624644
# 3      Albania          ALB  2.218752  3.314805  3.802197  4.071301  2.240070
# 4      Andorra          AND  1.434140  3.709678  0.346072  1.588765  1.849238

# %% [markdown]
# ## Dealing with Null value
# 1. drop null value
# 2. Fill value - median, mean, forward, backward methods

# %%
# Drop null value
selected_df_drop = selected_df.dropna(subset = ['2019'])

# Let's check how many were dropped.
print('Before:\t', len(selected_df))
print('After:\t', len(selected_df_drop))
print('Dropped:\t', (len(selected_df) - len(selected_df_drop)))
# Out:
# Before:	 264
# After:	 234
# Dropped:	 30

# %%
selected_df_drop.isnull().sum()
# Out:
# Country Name    0
# Country Code    0
# 2015            0
# 2016            0
# 2017            0
# 2018            0
# 2019            0
# dtype: int64

# %% [markdown]
# この時点でNull valueはゼロですが、以下に参考までにNull valueがあった場合のFillの方法をお伝えしておきます。

# %%
# Fill value
# by median value
median_value = selected_df_drop['2015'].median()
print('2015 median value: ', median_value)
# Out:
# 2015 median value:  2.98838062926432

# %%
# fill null value by fillna method
selected_df_drop['2015'].fillna(value = median_value)
# Out:
# 1       1.451315
# 2       0.943572
# 3       2.218752
# 4       1.434140
# 5       3.243312
#          ...
# 259     4.095194
# 260   -27.994439
# 261     1.193733
# 262     2.920375
# 263     1.779873
# Name: 2015, Length: 234, dtype: float64

# %%
# by forward fill
selected_df_drop.fillna(method = 'ffill', axis = 0)
# Out:
#      Country Name Country Code       2015      2016      2017      2018  \
# 1     Afghanistan          AFG   1.451315  2.260314  2.647003  1.189228
# 2          Angola          AGO   0.943572 -2.580050 -0.147213 -2.003630
# 3         Albania          ALB   2.218752  3.314805  3.802197  4.071301
# 4         Andorra          AND   1.434140  3.709678  0.346072  1.588765
# 5      Arab World          ARB   3.243312  3.507128  0.820847  2.079469
# ..            ...          ...        ...       ...       ...       ...
# 259        Kosovo          XKX   4.095194  4.070950  4.225630  3.815620
# 260   Yemen, Rep.          YEM -27.994439 -9.375060 -5.072010  0.752599
# 261  South Africa          ZAF   1.193733  0.399088  1.414513  0.787056
# 262        Zambia          ZMB   2.920375  3.776679  3.504336  4.034378
# 263      Zimbabwe          ZWE   1.779873  0.755869  4.704035  4.829674
#
#          2019
# 1    3.911603
# 2   -0.624644
# 3    2.240070
# 4    1.849238
# 5    1.487633
# ..        ...
# 259  4.171659
# 260  2.097414
# 261  0.152583
# 262  1.441785
# 263 -8.100000
#
# [234 rows x 7 columns]

# %%
# by backward fill
selected_df_drop.fillna(method = 'bfill', axis = 0)
# Out:
#      Country Name Country Code       2015      2016      2017      2018  \
# 1     Afghanistan          AFG   1.451315  2.260314  2.647003  1.189228
# 2          Angola          AGO   0.943572 -2.580050 -0.147213 -2.003630
# 3         Albania          ALB   2.218752  3.314805  3.802197  4.071301
# 4         Andorra          AND   1.434140  3.709678  0.346072  1.588765
# 5      Arab World          ARB   3.243312  3.507128  0.820847  2.079469
# ..            ...          ...        ...       ...       ...       ...
# 259        Kosovo          XKX   4.095194  4.070950  4.225630  3.815620
# 260   Yemen, Rep.          YEM -27.994439 -9.375060 -5.072010  0.752599
# 261  South Africa          ZAF   1.193733  0.399088  1.414513  0.787056
# 262        Zambia          ZMB   2.920375  3.776679  3.504336  4.034378
# 263      Zimbabwe          ZWE   1.779873  0.755869  4.704035  4.829674
#
#          2019
# 1    3.911603
# 2   -0.624644
# 3    2.240070
# 4    1.849238
# 5    1.487633
# ..        ...
# 259  4.171659
# 260  2.097414
# 261  0.152583
# 262  1.441785
# 263 -8.100000
#
# [234 rows x 7 columns]

# %%
selected_df_drop.head()
# Out:
#   Country Name Country Code      2015      2016      2017      2018      2019
# 1  Afghanistan          AFG  1.451315  2.260314  2.647003  1.189228  3.911603
# 2       Angola          AGO  0.943572 -2.580050 -0.147213 -2.003630 -0.624644
# 3      Albania          ALB  2.218752  3.314805  3.802197  4.071301  2.240070
# 4      Andorra          AND  1.434140  3.709678  0.346072  1.588765  1.849238
# 5   Arab World          ARB  3.243312  3.507128  0.820847  2.079469  1.487633

# %% [markdown]
# # Merge Two dataset
# A very friendly method with Python is data merge, which can be done with `.merge`, `.join`, `.concatenate`. We'll use `.merge` method. For more details, take a look at [this pandas tutorial](https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html).
# <br>
# <br>
# Let's import another file that contains country classification taken from [here](https://datahelpdesk.worldbank.org/knowledgebase/articles/906519-world-bank-country-and-lending-groups).

# %%
df_class = pd.read_excel('data/WB_country_classification.xls', sheet_name = 'List of economies', header = 4)

# %%
df_class.head()
# Out:
#    x  x.1         Economy Code    X                      Region  \
# 0  x    x               x    x    x                           x
# 1  1  NaN     Afghanistan  AFG  NaN                  South Asia
# 2  2  NaN         Albania  ALB  NaN       Europe & Central Asia
# 3  3  NaN         Algeria  DZA  NaN  Middle East & North Africa
# 4  4  NaN  American Samoa  ASM  NaN         East Asia & Pacific
#
#           Income group Lending category Other
# 0                    x                x     x
# 1           Low income              IDA  HIPC
# 2  Upper middle income             IBRD   NaN
# 3  Lower middle income             IBRD   NaN
# 4  Upper middle income               ..   NaN

# %% [markdown]
# ## Selecting with .loc and .iloc
# Select a single row and column
# - `.loc`: `df.loc[row_label, col_label]`
# - `.iloc`: `df.iloc[row_index, col_index]`
#
# Select multiple rows and columns
# - `.loc`: `df.loc[row_label_start:row_label:end, col_label_start:col_label_end]`
# - `.iloc`: `df.loc[row_index_start:row_index:end, col_index_start:col_index_end]`

# %%
df_class.loc[1, 'Economy']
# Out:
# 'Afghanistan'

# %%
df_class.loc[1, 'Region']
# Out:
# 'South Asia'

# %%
df_class.loc[1, ['Economy', 'Region']]
# Out:
# Economy    Afghanistan
# Region      South Asia
# Name: 1, dtype: object

# %%
df_class.loc[1, 'Economy':'Lending category']
# Out:
# Economy             Afghanistan
# Code                        AFG
# X                           NaN
# Region               South Asia
# Income group         Low income
# Lending category            IDA
# Name: 1, dtype: object

# %%
df_class.loc[1, 'Economy':]
# Out:
# Economy             Afghanistan
# Code                        AFG
# X                           NaN
# Region               South Asia
# Income group         Low income
# Lending category            IDA
# Other                      HIPC
# Name: 1, dtype: object

# %%
df_class.loc[1, :'Lending category']
# Out:
# x                             1
# x.1                         NaN
# Economy             Afghanistan
# Code                        AFG
# X                           NaN
# Region               South Asia
# Income group         Low income
# Lending category            IDA
# Name: 1, dtype: object

# %%
df_class.loc[1, :]
# Out:
# x                             1
# x.1                         NaN
# Economy             Afghanistan
# Code                        AFG
# X                           NaN
# Region               South Asia
# Income group         Low income
# Lending category            IDA
# Other                      HIPC
# Name: 1, dtype: object

# %%
# .iloc
df_class.iloc[1, 2]
# Out:
# 'Afghanistan'

# %%
df_class.iloc[1, 3]
# Out:
# 'AFG'

# %%
df_class.iloc[1:4, :]
# Out:
#    x  x.1      Economy Code    X                      Region  \
# 1  1  NaN  Afghanistan  AFG  NaN                  South Asia
# 2  2  NaN      Albania  ALB  NaN       Europe & Central Asia
# 3  3  NaN      Algeria  DZA  NaN  Middle East & North Africa
#
#           Income group Lending category Other
# 1           Low income              IDA  HIPC
# 2  Upper middle income             IBRD   NaN
# 3  Lower middle income             IBRD   NaN

# %%
df_class.head()
# Out:
#    x  x.1         Economy Code    X                      Region  \
# 0  x    x               x    x    x                           x
# 1  1  NaN     Afghanistan  AFG  NaN                  South Asia
# 2  2  NaN         Albania  ALB  NaN       Europe & Central Asia
# 3  3  NaN         Algeria  DZA  NaN  Middle East & North Africa
# 4  4  NaN  American Samoa  ASM  NaN         East Asia & Pacific
#
#           Income group Lending category Other
# 0                    x                x     x
# 1           Low income              IDA  HIPC
# 2  Upper middle income             IBRD   NaN
# 3  Lower middle income             IBRD   NaN
# 4  Upper middle income               ..   NaN

# %%
# Clean the dataframe
## .loc[1:, [column_name]] is to select row from line 1, and to select columns.
## .reset_index is to reset index number.
df_class = df_class.loc[1:, ['Economy', 'Code', 'Region', 'Income group']].reset_index(drop = True)

# %%
df_class.head()
# Out:
#           Economy Code                      Region         Income group
# 0     Afghanistan  AFG                  South Asia           Low income
# 1         Albania  ALB       Europe & Central Asia  Upper middle income
# 2         Algeria  DZA  Middle East & North Africa  Lower middle income
# 3  American Samoa  ASM         East Asia & Pacific  Upper middle income
# 4         Andorra  AND       Europe & Central Asia          High income

# %%
df_class.tail(10)
# Out:
#                  Economy Code Region Income group
# 264  Upper middle income  UMC    NaN          NaN
# 265                World  WLD    NaN          NaN
# 266                  NaN  NaN    NaN          NaN
# 267                  NaN  NaN    NaN          NaN
# 268                  NaN  NaN    NaN          NaN
# 269                  NaN  NaN    NaN          NaN
# 270                  NaN  NaN    NaN          NaN
# 271                  NaN  NaN    NaN          NaN
# 272                  NaN  NaN    NaN          NaN
# 273                  NaN  NaN    NaN          NaN

# %%
# Let's trim rows after world.
df_class = df_class.iloc[:265, :]
df_class.tail()
# Out:
#                                         Economy Code Region Income group
# 260                     South Asia (IDA & IBRD)  TSA    NaN          NaN
# 261                          Sub-Saharan Africa  SSF    NaN          NaN
# 262  Sub-Saharan Africa (excluding high income)  SSA    NaN          NaN
# 263             Sub-Saharan Africa (IDA & IBRD)  TSS    NaN          NaN
# 264                         Upper middle income  UMC    NaN          NaN

# %%
# Let's check null values
df_class.isnull().sum()
# Out:
# Economy          2
# Code             2
# Region          47
# Income group    47
# dtype: int64

# %%
# Finding which values are null in the "Code" column.
df_class[df_class['Code'].isnull()]
# Out:
#     Economy Code Region Income group
# 218     NaN  NaN    NaN          NaN
# 219     NaN  NaN    NaN          NaN

# %%
df_class = df_class.drop(index = [218, 219], axis = 0).reset_index(drop = True)

# %%
df_class.isnull().sum()
# Out:
# Economy          0
# Code             0
# Region          45
# Income group    45
# dtype: int64

# %%
# Investigate Null value of the Region column
df_class[df_class['Region'].isnull()]
# Out:
#                                                Economy Code Region  \
# 218                                         Arab World  ARB    NaN
# 219                             Caribbean small states  CSS    NaN
# 220                     Central Europe and the Baltics  CEB    NaN
# 221                         Early-demographic dividend  EAR    NaN
# 222                                East Asia & Pacific  EAS    NaN
# 223        East Asia & Pacific (excluding high income)  EAP    NaN
# 224                   East Asia & Pacific (IDA & IBRD)  TEA    NaN
# 225                                          Euro area  EMU    NaN
# 226                              Europe & Central Asia  ECS    NaN
# 227      Europe & Central Asia (excluding high income)  ECA    NaN
# 228                 Europe & Central Asia (IDA & IBRD)  TEC    NaN
# 229                                     European Union  EUU    NaN
# 230           Fragile and conflict affected situations  FCS    NaN
# 231             Heavily indebted poor countries (HIPC)  HPC    NaN
# 232                                        High income  HIC    NaN
# 233                                          IBRD only  IBD    NaN
# 234                                   IDA & IBRD total  IBT    NaN
# 235                                          IDA blend  IDB    NaN
# 236                                           IDA only  IDX    NaN
# 237                                          IDA total  IDA    NaN
# 238                          Late-demographic dividend  LTE    NaN
# 239                          Latin America & Caribbean  LCN    NaN
# 240  Latin America & Caribbean (excluding high income)  LAC    NaN
# 241             Latin America & Caribbean (IDA & IBRD)  TLA    NaN
# 242       Least developed countries: UN classification  LDC    NaN
# 243                                Low & middle income  LMY    NaN
# 244                                         Low income  LIC    NaN
# 245                                Lower middle income  LMC    NaN
# 246                         Middle East & North Africa  MEA    NaN
# 247  Middle East & North Africa (excluding high inc...  MNA    NaN
# 248            Middle East & North Africa (IDA & IBRD)  TMN    NaN
# 249                                      Middle income  MIC    NaN
# 250                                      North America  NAC    NaN
# 251                                       OECD members  OED    NaN
# 252                                 Other small states  OSS    NaN
# 253                        Pacific island small states  PSS    NaN
# 254                          Post-demographic dividend  PST    NaN
# 255                           Pre-demographic dividend  PRE    NaN
# 256                                       Small states  SST    NaN
# 257                                         South Asia  SAS    NaN
# 258                            South Asia (IDA & IBRD)  TSA    NaN
# 259                                 Sub-Saharan Africa  SSF    NaN
# 260         Sub-Saharan Africa (excluding high income)  SSA    NaN
# 261                    Sub-Saharan Africa (IDA & IBRD)  TSS    NaN
# 262                                Upper middle income  UMC    NaN
#
#     Income group
# 218          NaN
# 219          NaN
# 220          NaN
# 221          NaN
# 222          NaN
# 223          NaN
# 224          NaN
# 225          NaN
# 226          NaN
# 227          NaN
# 228          NaN
# 229          NaN
# 230          NaN
# 231          NaN
# 232          NaN
# 233          NaN
# 234          NaN
# 235          NaN
# 236          NaN
# 237          NaN
# 238          NaN
# 239          NaN
# 240          NaN
# 241          NaN
# 242          NaN
# 243          NaN
# 244          NaN
# 245          NaN
# 246          NaN
# 247          NaN
# 248          NaN
# 249          NaN
# 250          NaN
# 251          NaN
# 252          NaN
# 253          NaN
# 254          NaN
# 255          NaN
# 256          NaN
# 257          NaN
# 258          NaN
# 259          NaN
# 260          NaN
# 261          NaN
# 262          NaN

# %%
df_class[df_class['Income group'].isnull()]
# Out:
#                                                Economy Code Region  \
# 218                                         Arab World  ARB    NaN
# 219                             Caribbean small states  CSS    NaN
# 220                     Central Europe and the Baltics  CEB    NaN
# 221                         Early-demographic dividend  EAR    NaN
# 222                                East Asia & Pacific  EAS    NaN
# 223        East Asia & Pacific (excluding high income)  EAP    NaN
# 224                   East Asia & Pacific (IDA & IBRD)  TEA    NaN
# 225                                          Euro area  EMU    NaN
# 226                              Europe & Central Asia  ECS    NaN
# 227      Europe & Central Asia (excluding high income)  ECA    NaN
# 228                 Europe & Central Asia (IDA & IBRD)  TEC    NaN
# 229                                     European Union  EUU    NaN
# 230           Fragile and conflict affected situations  FCS    NaN
# 231             Heavily indebted poor countries (HIPC)  HPC    NaN
# 232                                        High income  HIC    NaN
# 233                                          IBRD only  IBD    NaN
# 234                                   IDA & IBRD total  IBT    NaN
# 235                                          IDA blend  IDB    NaN
# 236                                           IDA only  IDX    NaN
# 237                                          IDA total  IDA    NaN
# 238                          Late-demographic dividend  LTE    NaN
# 239                          Latin America & Caribbean  LCN    NaN
# 240  Latin America & Caribbean (excluding high income)  LAC    NaN
# 241             Latin America & Caribbean (IDA & IBRD)  TLA    NaN
# 242       Least developed countries: UN classification  LDC    NaN
# 243                                Low & middle income  LMY    NaN
# 244                                         Low income  LIC    NaN
# 245                                Lower middle income  LMC    NaN
# 246                         Middle East & North Africa  MEA    NaN
# 247  Middle East & North Africa (excluding high inc...  MNA    NaN
# 248            Middle East & North Africa (IDA & IBRD)  TMN    NaN
# 249                                      Middle income  MIC    NaN
# 250                                      North America  NAC    NaN
# 251                                       OECD members  OED    NaN
# 252                                 Other small states  OSS    NaN
# 253                        Pacific island small states  PSS    NaN
# 254                          Post-demographic dividend  PST    NaN
# 255                           Pre-demographic dividend  PRE    NaN
# 256                                       Small states  SST    NaN
# 257                                         South Asia  SAS    NaN
# 258                            South Asia (IDA & IBRD)  TSA    NaN
# 259                                 Sub-Saharan Africa  SSF    NaN
# 260         Sub-Saharan Africa (excluding high income)  SSA    NaN
# 261                    Sub-Saharan Africa (IDA & IBRD)  TSS    NaN
# 262                                Upper middle income  UMC    NaN
#
#     Income group
# 218          NaN
# 219          NaN
# 220          NaN
# 221          NaN
# 222          NaN
# 223          NaN
# 224          NaN
# 225          NaN
# 226          NaN
# 227          NaN
# 228          NaN
# 229          NaN
# 230          NaN
# 231          NaN
# 232          NaN
# 233          NaN
# 234          NaN
# 235          NaN
# 236          NaN
# 237          NaN
# 238          NaN
# 239          NaN
# 240          NaN
# 241          NaN
# 242          NaN
# 243          NaN
# 244          NaN
# 245          NaN
# 246          NaN
# 247          NaN
# 248          NaN
# 249          NaN
# 250          NaN
# 251          NaN
# 252          NaN
# 253          NaN
# 254          NaN
# 255          NaN
# 256          NaN
# 257          NaN
# 258          NaN
# 259          NaN
# 260          NaN
# 261          NaN
# 262          NaN

# %%
# OK, looks like null values of Region and Income group are regional data. Let's drop them.
df_class = df_class.dropna()

# %%
df_class.isnull().sum()
# Out:
# Economy         0
# Code            0
# Region          0
# Income group    0
# dtype: int64

# %% [markdown]
# Now we have two dataframes: `selected_df_drop` and `df_class`. One important element is with which **key** is to be used for joining the two dataframes.

# %%
print('GDP dataframe: ', sorted(selected_df_drop['Country Code'])[:10])
print('\nCountry class dataframe: ', sorted(df_class['Code'])[:10])
# Out:
# GDP dataframe:  ['AFG', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG', 'ARM', 'ATG', 'AUS']
#
# Country class dataframe:  ['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM', 'ATG']

# %% [markdown]
# It seems like the country code is good to go. Let's merge them.

# %%
merged_df = pd.merge(selected_df_drop, df_class, how = 'inner', left_on = 'Country Code', right_on = 'Code')

# %%
merged_df.head()
# Out:
#            Country Name Country Code      2015      2016      2017      2018  \
# 0           Afghanistan          AFG  1.451315  2.260314  2.647003  1.189228
# 1                Angola          AGO  0.943572 -2.580050 -0.147213 -2.003630
# 2               Albania          ALB  2.218752  3.314805  3.802197  4.071301
# 3               Andorra          AND  1.434140  3.709678  0.346072  1.588765
# 4  United Arab Emirates          ARE  5.105937  3.060964  2.373537  1.189856
#
#        2019               Economy Code                      Region  \
# 0  3.911603           Afghanistan  AFG                  South Asia
# 1 -0.624644                Angola  AGO          Sub-Saharan Africa
# 2  2.240070               Albania  ALB       Europe & Central Asia
# 3  1.849238               Andorra  AND       Europe & Central Asia
# 4  1.677720  United Arab Emirates  ARE  Middle East & North Africa
#
#           Income group
# 0           Low income
# 1  Lower middle income
# 2  Upper middle income
# 3          High income
# 4          High income

# %%
merged_df = merged_df.drop(columns = ['Economy','Code'])

# %%
print(merged_df.shape)
merged_df.head()
# Out:
# (188, 9)
#            Country Name Country Code      2015      2016      2017      2018  \
# 0           Afghanistan          AFG  1.451315  2.260314  2.647003  1.189228
# 1                Angola          AGO  0.943572 -2.580050 -0.147213 -2.003630
# 2               Albania          ALB  2.218752  3.314805  3.802197  4.071301
# 3               Andorra          AND  1.434140  3.709678  0.346072  1.588765
# 4  United Arab Emirates          ARE  5.105937  3.060964  2.373537  1.189856
#
#        2019                      Region         Income group
# 0  3.911603                  South Asia           Low income
# 1 -0.624644          Sub-Saharan Africa  Lower middle income
# 2  2.240070       Europe & Central Asia  Upper middle income
# 3  1.849238       Europe & Central Asia          High income
# 4  1.677720  Middle East & North Africa          High income

# %% [markdown]
# Voilà!! You've well done to merge datasets.

# %%
# Let's take a quick investigation.
merged_df['Income group'].value_counts()
# Out:
# High income            64
# Upper middle income    51
# Lower middle income    49
# Low income             24
# Name: Income group, dtype: int64

# %%
# We can also find percent
merged_df['Income group'].value_counts(normalize = True)
# Out:
# High income            0.340426
# Upper middle income    0.271277
# Lower middle income    0.260638
# Low income             0.127660
# Name: Income group, dtype: float64

# %%
# Similarly look at region
merged_df['Region'].value_counts()
# Out:
# Europe & Central Asia         49
# Sub-Saharan Africa            45
# Latin America & Caribbean     34
# East Asia & Pacific           29
# Middle East & North Africa    20
# South Asia                     8
# North America                  3
# Name: Region, dtype: int64

# %%
merged_df['Region'].value_counts(normalize = True)
# Out:
# Europe & Central Asia         0.260638
# Sub-Saharan Africa            0.239362
# Latin America & Caribbean     0.180851
# East Asia & Pacific           0.154255
# Middle East & North Africa    0.106383
# South Asia                    0.042553
# North America                 0.015957
# Name: Region, dtype: float64

# %% [markdown]
# # Groupby
# It would be more interesting if we could aggregate GDP growth at a regional/income level. Let's do it with `.groupby` method.

# %%
region_df = merged_df.groupby('Region').mean()

# %%
region_df
# Out:
#                                 2015      2016      2017      2018      2019
# Region
# East Asia & Pacific         3.513334  3.901937  3.705981  3.640636  3.360659
# Europe & Central Asia       2.808995  2.689608  3.614497  3.435334  2.920932
# Latin America & Caribbean   2.267685  2.004803  1.835967  2.230917  1.394246
# Middle East & North Africa  1.290085  3.624767  2.794409  2.477286  1.394086
# North America               1.447576  0.660676  3.050650  1.502721  1.425702
# South Asia                  4.823591  5.337089  5.774157  5.275041  4.869965
# Sub-Saharan Africa          2.912462  3.013566  3.438389  3.491421  3.185140

# %%
region_and_income_df = merged_df.groupby(['Region', 'Income group']).mean()
region_and_income_df
# Out:
#                                                      2015      2016      2017  \
# Region                     Income group
# East Asia & Pacific        High income           0.447581  1.562178  2.247197
#                            Lower middle income   5.288981  5.242629  4.480959
#                            Upper middle income   4.904009  4.983184  4.463865
# Europe & Central Asia      High income           3.307363  2.740618  3.402564
#                            Low income            6.008288  6.872964  7.617493
#                            Lower middle income   0.303084  4.268505  4.089573
#                            Upper middle income   2.228516  1.830376  3.646973
# Latin America & Caribbean  High income           2.573883  1.755132  0.428162
#                            Low income            1.616915  1.722545  2.286127
#                            Lower middle income   3.971088  3.816588  3.979721
#                            Upper middle income   1.738184  1.770441  2.194893
# Middle East & North Africa High income           4.196586  3.406262  1.451420
#                            Low income          -27.994439 -9.375060 -5.072010
#                            Lower middle income   4.203387  4.213895  3.078261
#                            Upper middle income  -0.999376  5.867387  6.175854
# North America              High income           1.447576  0.660676  3.050650
# South Asia                 Low income            1.451315  2.260314  2.647003
#                            Lower middle income   5.708810  5.683144  6.055963
#                            Upper middle income   2.884549  6.337530  7.210480
# Sub-Saharan Africa         High income           4.245229  4.200278  4.095074
#                            Low income            3.287832  4.102512  4.207232
#                            Lower middle income   3.223459  2.636805  3.529185
#                            Upper middle income  -0.241715 -0.460566 -0.226524
#
#                                                     2018      2019
# Region                     Income group
# East Asia & Pacific        High income          3.123294  0.206030
#                            Lower middle income  4.450543  5.831040
#                            Upper middle income  3.173693  3.907170
# Europe & Central Asia      High income          3.087098  2.405079
#                            Low income           7.300000  7.011269
#                            Lower middle income  4.227783  4.221210
#                            Upper middle income  3.679093  3.362658
# Latin America & Caribbean  High income          1.869120  1.455960
#                            Low income           1.667827 -1.681985
#                            Lower middle income  1.600362  0.843196
#                            Upper middle income  2.623422  1.649890
# Middle East & North Africa High income          2.285051  1.471755
#                            Low income           0.752599  2.097414
#                            Lower middle income  3.660303  3.100358
#                            Upper middle income  1.710179 -0.918377
# North America              High income          1.502721  1.425702
# South Asia                 Low income           1.189228  3.911603
#                            Lower middle income  5.480382  4.676907
#                            Upper middle income  8.128814  6.986676
# Sub-Saharan Africa         High income          3.756609  4.163639
#                            Low income           4.478640  4.360969
#                            Lower middle income  3.309836  2.635077
#                            Upper middle income  0.090175  0.070650

# %%
# Let's deep dive into Africa
africa_df = merged_df[merged_df['Region'] == 'Sub-Saharan Africa'].reset_index(drop = True)

# find major statistics in 2015 and 2019
africa_group_df = africa_df.groupby(['Income group']).agg({'2015':['mean', 'max', 'min', 'median'],
                                                          '2019':['mean', 'max', 'min', 'median']})

# %%
africa_group_df
# Out:
#                          2015                                      2019  \
#                          mean        max        min    median      mean
# Income group
# High income          4.245229   4.937386   3.553072  4.245229  4.163639
# Low income           3.287832  10.392463 -20.598771  4.364885  4.360969
# Lower middle income  3.223459   8.842860  -3.235258  2.651419  2.635077
# Upper middle income -0.241715   4.526767  -9.110041  1.193733  0.070650
#
#
#                           max       min    median
# Income group
# High income          5.312514  3.014763  4.163639
# Low income           9.428675 -2.503537  4.801171
# Lower middle income  6.865687 -8.100000  2.982315
# Upper middle income  3.944946 -5.576308  0.152583

# %% [markdown]
# There is a downward trend in high income, while lower income is an upward trend. Let's go back to the countries in each classification.

# %%
africa_df[africa_df['Income group'] == 'High income']
# Out:
#    Country Name Country Code      2015      2016      2017      2018  \
# 26    Mauritius          MUS  3.553072  3.837933  3.814152  3.759677
# 37   Seychelles          SYC  4.937386  4.562623  4.375996  3.753541
#
#         2019              Region Income group
# 26  3.014763  Sub-Saharan Africa  High income
# 37  5.312514  Sub-Saharan Africa  High income

# %%
africa_df[africa_df['Income group'] == 'Low income']
# Out:
#                 Country Name Country Code       2015       2016       2017  \
# 1                    Burundi          BDI  -3.900003  -0.600020   0.500010
# 3               Burkina Faso          BFA   3.921229   5.957977   6.203489
# 5   Central African Republic          CAF   4.337121   4.750317   4.527278
# 8           Congo, Dem. Rep.          COD   6.916188   2.399379   3.726948
# 12                  Ethiopia          ETH  10.392463   9.433483   9.564190
# 15                    Guinea          GIN   3.814950  10.828807  10.299907
# 16               Gambia, The          GMB   4.058074   1.943360   4.822611
# 17             Guinea-Bissau          GNB   6.134083   6.262806   5.919177
# 20                   Liberia          LBR   0.000000  -1.599584   2.468626
# 22                Madagascar          MDG   3.132296   3.993146   3.933316
# 23                      Mali          MLI   6.171800   5.852299   5.305456
# 24                Mozambique          MOZ   6.723279   3.824214   3.741318
# 27                    Malawi          MWI   2.800000   2.484041   4.000031
# 29                     Niger          NER   4.392649   5.709274   4.999097
# 31                    Rwanda          RWA   8.856844   5.970744   3.976290
# 32                     Sudan          SDN   4.906042   4.699976   0.767862
# 34              Sierra Leone          SLE -20.598771   6.055474   4.211183
# 38                      Chad          TCD   2.767676  -6.255527  -2.988696
# 39                      Togo          TGO   5.742868   5.559079   4.357414
# 41                    Uganda          UGA   5.187860   4.781000   3.809129
#
#         2018      2019              Region Income group
# 1   1.609933  1.842477  Sub-Saharan Africa   Low income
# 3   6.731236  5.699435  Sub-Saharan Africa   Low income
# 5   3.789444  2.970276  Sub-Saharan Africa   Low income
# 8   5.821121  4.384529  Sub-Saharan Africa   Low income
# 12  6.816148  8.364086  Sub-Saharan Africa   Low income
# 15  6.199775  5.600000  Sub-Saharan Africa   Low income
# 16  7.234890  6.056766  Sub-Saharan Africa   Low income
# 17  3.800000  4.600094  Sub-Saharan Africa   Low income
# 20  1.222551 -2.278245  Sub-Saharan Africa   Low income
# 22  4.564783  4.851000  Sub-Saharan Africa   Low income
# 23  4.746484  4.751342  Sub-Saharan Africa   Low income
# 24  3.443814  2.283597  Sub-Saharan Africa   Low income
# 27  3.170003  4.369239  Sub-Saharan Africa   Low income
# 29  7.219173  5.902792  Sub-Saharan Africa   Low income
# 31  8.579425  9.428675  Sub-Saharan Africa   Low income
# 32 -2.289949 -2.503537  Sub-Saharan Africa   Low income
# 34  3.446163  5.507686  Sub-Saharan Africa   Low income
# 38  2.374038  3.247182  Sub-Saharan Africa   Low income
# 39  4.931155  5.338670  Sub-Saharan Africa   Low income
# 41  6.162619  6.803327  Sub-Saharan Africa   Low income

# %%
# How is the trend if we would make a binary income category.
africa_df['Income group'].unique()
# Out:
# array(['Lower middle income', 'Low income', 'Upper middle income',
#        'High income'], dtype=object)

# %%
binary_class_list = []
for element in africa_df['Income group']:
    if element == 'High income':
        binary_class = 'upper_category'
        
    elif element == 'Upper middle income':
        binary_class = 'upper_category'  
        
    elif element == 'Lower middle income':
        binary_class = 'lower_category'
        
    elif element == 'Low income':
        binary_class = 'lower_category'
        
    binary_class_list.append(binary_class)
        
africa_df['binary_class'] = binary_class_list

# %%
africa_df.head()
# Out:
#    Country Name Country Code      2015      2016      2017      2018  \
# 0        Angola          AGO  0.943572 -2.580050 -0.147213 -2.003630
# 1       Burundi          BDI -3.900003 -0.600020  0.500010  1.609933
# 2         Benin          BEN  1.778151  3.339673  5.671555  6.697259
# 3  Burkina Faso          BFA  3.921229  5.957977  6.203489  6.731236
# 4      Botswana          BWA -1.697935  4.303767  2.903998  4.478837
#
#        2019              Region         Income group    binary_class
# 0 -0.624644  Sub-Saharan Africa  Lower middle income  lower_category
# 1  1.842477  Sub-Saharan Africa           Low income  lower_category
# 2  6.865687  Sub-Saharan Africa  Lower middle income  lower_category
# 3  5.699435  Sub-Saharan Africa           Low income  lower_category
# 4  2.966126  Sub-Saharan Africa  Upper middle income  upper_category

# %%
africa_df['binary_class'].value_counts()
# Out:
# lower_category    38
# upper_category     7
# Name: binary_class, dtype: int64

# %%
africa_df.groupby('binary_class').mean()
# Out:
#                     2015      2016      2017      2018      2019
# binary_class
# lower_category  3.257340  3.408230  3.886052  3.924996  3.543441
# upper_category  1.040269  0.871104  1.008218  1.137727  1.240075

# %%
africa_df.groupby('binary_class').mean().T.plot();

# %% [markdown]
# ---

# %%
# This cell is to create a config file.
# Hiding this cell for authority

# Hiding celll from https://gist.github.com/Zsailer/5d1f4e357c78409dd9a5a4e5c61be552
from IPython.display import HTML
from IPython.display import display

# Taken from https://stackoverflow.com/questions/31517194/how-to-hide-one-specific-cell-input-or-output-in-ipython-notebook
tag = HTML('''<script>
code_show=true; 
function code_toggle() {
    if (code_show){
        $('div.cell.code_cell.rendered.selected div.input').hide();
    } else {
        $('div.cell.code_cell.rendered.selected div.input').show();
    }
    code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
Creating requirements.txt file. To show/hide this cell's raw code input, click <a href="javascript:code_toggle()">here</a>.''')
display(tag)

############### Write code below ##################
# Config file to freeze packages in a notebook
# from https://stackoverflow.com/questions/40428931/package-for-listing-version-of-packages-used-in-a-jupyter-notebook
import pkg_resources
import types

def get_requirements():
    def get_imports():
        for name, val in globals().items():
            if isinstance(val, types.ModuleType):
                # Split ensures you get root package, 
                # not just imported function
                name = val.__name__.split(".")[0]

            elif isinstance(val, type):
                name = val.__module__.split(".")[0]

            # Some packages are weird and have different
            # imported names vs. system/pip names. Unfortunately,
            # there is no systematic way to get pip names from
            # a package's imported name. You'll have to add
            # exceptions to this list manually!
            poorly_named_packages = {
                "PIL": "Pillow",
                "sklearn": "scikit-learn"
            }
            if name in poorly_named_packages.keys():
                name = poorly_named_packages[name]

            yield name
    imports = list(set(get_imports()))

    # The only way I found to get the version of the root package
    # from only the name of the package is to cross-check the names 
    # of installed packages vs. imported packages
    requirements = []
    for m in pkg_resources.working_set:
        if m.project_name in imports and m.project_name!="pip":
            requirements.append((m.project_name, m.version))

    
    with open("requirements.txt", "w") as f:
        print('Create "requirements.txt"')
        for r in requirements:
            string = r[0] + '==' + r[1] + '\n'
            f.write(string)
            print("\t{}=={}".format(*r))
    print('"requirements.txt" was created.')
        
get_requirements()
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#     if (code_show){
#         $('div.cell.code_cell.rendered.selected div.input').hide();
#     } else {
#         $('div.cell.code_cell.rendered.selected div.input').show();
#     }
#     code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# Creating requirements.txt file. To show/hide this cell's raw code input, click <a href="javascript:code_toggle()">here</a>.
# Create "requirements.txt"
# 	pandas==1.2.4
# 	matplotlib==3.3.4
# "requirements.txt" was created.
